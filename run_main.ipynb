# %%
# !git clone https://github.com/CodeWithAmal06/QuantumPrompt-to-ManimLLM.git
# %cd QuantumPrompt-to-ManimLLM
# Out:
# Cloning into 'QuantumPrompt-to-ManimLLM'...
# remote: Enumerating objects: 277, done.
# remote: Counting objects: 100% (277/277), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 277 (delta 130), reused 225 (delta 81), pack-reused 0 (from 0)
# Receiving objects: 100% (277/277), 3.92 MiB | 7.41 MiB/s, done.
# Resolving deltas: 100% (130/130), done.
# /content/QuantumPrompt-to-ManimLLM

# %%
# !apt-get update -y && apt-get install -y texlive texlive-latex-extra texlive-fonts-extra texlive-latex-recommended dvisvgm ffmpeg
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [102 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,899 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,154 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,190 kB]
# ...

# %%
# !apt-get update -qq
# !apt-get install -y -qq libcairo2-dev libpango1.0-dev pkg-config ffmpeg texlive-latex-extra
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# (Reading database ... 248649 files and directories currently installed.)
# Removing r-base-dev (4.6.0-4.2204.0) ...
# dpkg: pkgconf: dependency problems, but removing anyway as you requested:
#  libsndfile1-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libmkl-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libglib2.0-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
#   Package pkgconf which provides pkg-config is to be removed.
#  libfontconfig-dev:amd64 depends on pkg-config; however:
#   Package pkg-config is not installed.
# ...

# %%
# %pip install json-repair
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# Install Manim, Unsloth, Rich, etc.
# %pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 82.6 MB/s eta 0:00:00:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 652.1/652.1 kB 53.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 MB 10.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 64.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 22.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.0/55.0 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 43.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Test Examples

# %%
# Run your newly created CLI script on the Colab GPU!
# !python main.py --prompt "Show a Hadamard gate being applied to a qubit in state |0>, illustrating the qubit state before and after the operation."
# Out:
# ╭────────────────────────────── Quantum-Manim-AI ──────────────────────────────╮
# │ Quantum-Manim-AI                                                             │
# │ Generate, compile, render, and visually audit Manim scenes via Qwen-2.5-7B.  │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# Attempt 1/3 Generating code...
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# Traceback (most recent call last):
#   File "/content/QuantumPrompt-to-ManimLLM/main.py", line 450, in <module>
#     main()
#   File "/content/QuantumPrompt-to-ManimLLM/main.py", line 443, in main
#     success = process_prompt(args.prompt, args.max_retries)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/QuantumPrompt-to-ManimLLM/main.py", line 358, in process_prompt
#     raw_output = generate_manim_code(current_prompt, attempt=attempt)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !python main.py --prompt "Create a 2D quantum circuit diagram with 2 qubit lines labeled |q0> and |q1>. Apply a Hadamard gate H to |q0>, followed by a CNOT gate where |q0| is the control (dot) and |q1| is the target (crossed circle). Add a step-by-step Write animation showing gate placement."
# Out:
# ╭────────────────────────────── Quantum-Manim-AI ──────────────────────────────╮
# │ Quantum-Manim-AI                                                             │
# │ Generate, compile, render, and visually audit Manim scenes via Qwen-2.5-7B.  │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# Attempt 1/3 Generating code...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:298: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ...

# %%
# !python main.py --prompt "Animate two 2D sine waves on axes representing quantum wavefunctions in constructive and destructive interference. First show Wave 1 in blue and Wave 2 in red in-phase combining to double amplitude, then shift Wave 2 out-of-phase to cancel out completely."
# Out:
# ╭────────────────────────────── Quantum-Manim-AI ──────────────────────────────╮
# │ Quantum-Manim-AI                                                             │
# │ Generate, compile, render, and visually audit Manim scenes via Qwen-2.5-7B.  │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# Attempt 1/3 Generating code...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/constants.py:298: FutureWarning: The `HF_HUB_ENABLE_HF_TRANSFER` environment variable is deprecated as 'hf_transfer' is not used anymore. Please use `HF_XET_HIGH_PERFORMANCE` instead to enable high performance transfer with Xet. Visit https://huggingface.co/docs/huggingface_hub/package_reference/environment_variables#hfxethighperformance for more details.
#   warnings.warn(
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ...

# %%
# !python main.py --prompt "Animate the 2D matrix multiplication of a Pauli-X gate acting on state vector |0>. Show the 2x2 matrix [[0, 1], [1, 0]] multiplied by vector [[1], [0]], smoothly transforming step-by-step into the output vector [[0], [1]] representing state |1>."
# Out:
# ╭────────────────────────────── Quantum-Manim-AI ──────────────────────────────╮
# │ Quantum-Manim-AI                                                             │
# │ Generate, compile, render, and visually audit Manim scenes via Qwen-2.5-7B.  │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# Attempt 1/3 Generating code...
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.8.7: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ...

# %%
# !python main.py --prompt "Create a 2D Manim scene demonstrating Bell State creation. Show two horizontal qubit rails |0> and |0>. Animate a Hadamard gate box H placing qubit 1 into superposition (|0> + |1>)/sqrt(2), then extend a vertical CNOT control line down to qubit 2 to create the entangled Bell State (|00> + |11>)/sqrt(2)."
# Out:
# ╭────────────────────────────── Quantum-Manim-AI ──────────────────────────────╮
# │ Quantum-Manim-AI                                                             │
# │ Generate, compile, render, and visually audit Manim scenes via Qwen-2.5-7B.  │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# Attempt 1/3 Generating code...
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.8.7: Fast Qwen2 patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.11.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ...
